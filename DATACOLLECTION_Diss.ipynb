# %% [markdown]
# # Import Libraries

# %%
# import libraries
import numpy as np
from numpy import median
from scipy import stats
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import random as rn
from functools import reduce

# Import and suppress warnings
import warnings
warnings.filterwarnings('ignore')
import os

# %% [markdown]
# # Import the dataset

# %%
# Read the file
df = pd.read_csv('Clean1.csv')

# %%
df
# Out:
#        Unnamed: 0   Age  Attrition BusinessTravel  DailyRate  \
# 0               0  41.0          1  Travel_Rarely     1102.0
# 1               1  41.0          1  Travel_Rarely     1102.0
# 2               2  41.0          1  Travel_Rarely     1102.0
# 3               3  41.0          1  Travel_Rarely     1102.0
# 4               4  41.0          1  Travel_Rarely     1102.0
# ...           ...   ...        ...            ...        ...
# 23199       23199  60.0          0  Travel_Rarely      370.0
# 23200       23200  60.0          0  Travel_Rarely      370.0
# 23201       23201  60.0          0  Travel_Rarely      370.0
# 23202       23202  60.0          0  Travel_Rarely      370.0
# 23203       23203  60.0          0  Travel_Rarely      370.0
#
#                    Department  DistanceFromHome  Education EducationField  \
# 0                       Sales               1.0        2.0  Life Sciences
# 1                       Sales               1.0        2.0  Life Sciences
# ...

# %%
column_index_to_drop = [0,11]
df = df.drop(df.columns[column_index_to_drop], axis=1)

# %%
df
# Out:
#         Age  Attrition BusinessTravel  DailyRate              Department  \
# 0      41.0          1  Travel_Rarely     1102.0                   Sales
# 1      41.0          1  Travel_Rarely     1102.0                   Sales
# 2      41.0          1  Travel_Rarely     1102.0                   Sales
# 3      41.0          1  Travel_Rarely     1102.0                   Sales
# 4      41.0          1  Travel_Rarely     1102.0                   Sales
# ...     ...        ...            ...        ...                     ...
# 23199  60.0          0  Travel_Rarely      370.0  Research & Development
# 23200  60.0          0  Travel_Rarely      370.0  Research & Development
# 23201  60.0          0  Travel_Rarely      370.0  Research & Development
# 23202  60.0          0  Travel_Rarely      370.0  Research & Development
# 23203  60.0          0  Travel_Rarely      370.0  Research & Development
#
#        DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (23204, 35)

# %%
df.dtypes
# Out:
# Age                         float64
# Attrition                     int64
# BusinessTravel               object
# DailyRate                   float64
# Department                   object
# DistanceFromHome            float64
# Education                   float64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber               object
# EnvironmentSatisfaction     float64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement              float64
# JobLevel                    float64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                 float64
# NumCompaniesWorked          float64
# Over18                       object
# OverTime                     object
# PercentSalaryHike             int64
# PerformanceRating           float64
# RelationshipSatisfaction    float64
# ...

# %% [markdown]
# # Inspect all of the columns and inspect the sructure of the dataframe

# %%
# Set options to inspect all of the columns
pd.options.display.max_columns = 36

# Inspect the structure of the dataframe
df.sample(5).transpose()
# Out:
#                                            69               21806  \
# Age                                         41.0             55.0
# Attrition                                      1                1
# BusinessTravel                     Travel_Rarely    Travel_Rarely
# DailyRate                                 1085.0            436.0
# Department                Research & Development            Sales
# DistanceFromHome                             2.0              2.0
# Education                                    4.0              1.0
# EducationField                     Life Sciences    Life Sciences
# EmployeeCount                                  1                1
# EmployeeNumber                             10720             9779
# EnvironmentSatisfaction                      2.0              3.0
# Gender                                    Female             Male
# HourlyRate                                    57               37
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=23204, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=23204, step=1),
#  Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#         'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#         'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#         'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#         'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#         'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#         'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#         'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#         'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#         'YearsWithCurrManager'],
#        dtype='object')]

# %%
#df.get_dtype_counts()
dtype_counts = df.dtypes.value_counts()
dtype_counts
# Out:
# float64    20
# object      9
# int64       6
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23204 entries, 0 to 23203
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23204 non-null  float64
#  1   Attrition                 23204 non-null  int64
#  2   BusinessTravel            23204 non-null  object
#  3   DailyRate                 23204 non-null  float64
#  4   Department                23204 non-null  object
#  5   DistanceFromHome          23204 non-null  float64
#  6   Education                 23204 non-null  float64
#  7   EducationField            23204 non-null  object
#  8   EmployeeCount             23204 non-null  int64
#  9   EmployeeNumber            23204 non-null  object
#  10  EnvironmentSatisfaction   23204 non-null  float64
#  11  Gender                    23204 non-null  object
#  12  HourlyRate                23204 non-null  int64
# ...

# %% [markdown]
# # Change the data type of columns

# %%
df = df.apply(lambda col: col.astype(int) if col.dtype == 'float64' else col)

# %%
df
# Out:
#        Age  Attrition BusinessTravel  DailyRate              Department  \
# 0       41          1  Travel_Rarely       1102                   Sales
# 1       41          1  Travel_Rarely       1102                   Sales
# 2       41          1  Travel_Rarely       1102                   Sales
# 3       41          1  Travel_Rarely       1102                   Sales
# 4       41          1  Travel_Rarely       1102                   Sales
# ...    ...        ...            ...        ...                     ...
# 23199   60          0  Travel_Rarely        370  Research & Development
# 23200   60          0  Travel_Rarely        370  Research & Development
# 23201   60          0  Travel_Rarely        370  Research & Development
# 23202   60          0  Travel_Rarely        370  Research & Development
# 23203   60          0  Travel_Rarely        370  Research & Development
#
#        DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#df.get_dtype_counts()
dtype_counts = df.dtypes.value_counts()
dtype_counts
# Out:
# int64     26
# object     9
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23204 entries, 0 to 23203
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23204 non-null  int64
#  1   Attrition                 23204 non-null  int64
#  2   BusinessTravel            23204 non-null  object
#  3   DailyRate                 23204 non-null  int64
#  4   Department                23204 non-null  object
#  5   DistanceFromHome          23204 non-null  int64
#  6   Education                 23204 non-null  int64
#  7   EducationField            23204 non-null  object
#  8   EmployeeCount             23204 non-null  int64
#  9   EmployeeNumber            23204 non-null  object
#  10  EnvironmentSatisfaction   23204 non-null  int64
#  11  Gender                    23204 non-null  object
#  12  HourlyRate                23204 non-null  int64
#  13  JobInvolvement            23204 non-null  int64
# ...

# %% [markdown]
# # Description about the dataset

# %%
df.describe(include="all")
# Out:
#                 Age     Attrition BusinessTravel     DailyRate  \
# count   23204.00000  23204.000000          23204  23204.000000
# unique          NaN           NaN              3           NaN
# top             NaN           NaN  Travel_Rarely           NaN
# freq            NaN           NaN          16457           NaN
# mean       36.91954      0.158335            NaN    802.328349
# std         9.11660      0.365062            NaN    403.193041
# min        18.00000      0.000000            NaN    102.000000
# 25%        30.00000      0.000000            NaN    465.000000
# 50%        36.00000      0.000000            NaN    802.000000
# 75%        43.00000      0.000000            NaN   1157.000000
# max        60.00000      1.000000            NaN   1499.000000
#
#                     Department  DistanceFromHome     Education EducationField  \
# count                    23204      23204.000000  23204.000000          23204
# ...

# %% [markdown]
# # Check weirdness on the dataset by looking some features

# %%
df['TotalWorkingYears'][df['TotalWorkingYears'] < 0].sum()
# Out:
# 0

# %%
df['MaritalStatus'].unique()
# Out:
# array(['Single', 'Divorced', 'Married'], dtype=object)

# %%
df['YearsAtCompany'][df['YearsAtCompany'] > 41].sum()
# Out:
# 0

# %% [markdown]
# # **Check for missing values**

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # Check for duplicate observations and remove them from the dataset

# %%
# Check for duplicate observations
df.duplicated().sum()
# Out:
# 15

# %%
duplicate_rows = df[df.duplicated()]
print("\nDuplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#        Age  Attrition BusinessTravel  DailyRate              Department  \
# 10      41          1  Travel_Rarely       1102                   Sales
# 11      41          1  Travel_Rarely       1102                   Sales
# 12      41          1  Travel_Rarely       1102                   Sales
# 660     37          1  Travel_Rarely        807         Human Resources
# 661     37          1  Travel_Rarely        807         Human Resources
# 662     37          1  Travel_Rarely        807         Human Resources
# 663     37          1  Travel_Rarely        807         Human Resources
# 6062    26          1  Travel_Rarely       1357  Research & Development
# 6063    26          1  Travel_Rarely       1357  Research & Development
# 6064    26          1  Travel_Rarely       1357  Research & Development
# 6065    26          1  Travel_Rarely       1357  Research & Development
# 11714   32          0     Non-Travel        953  Research & Development
# ...

# %%
duplicates = df.duplicated()
print("\nDuplicate Rows (True indicates duplicate):")
print(duplicates)

# Drop duplicate rows
df1 = df.drop_duplicates()

print("\nDataFrame After Dropping Duplicates:")
print(df1)
# Out:
# Duplicate Rows (True indicates duplicate):
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23199    False
# 23200    False
# 23201    False
# 23202    False
# 23203    False
# Length: 23204, dtype: bool
#
# DataFrame After Dropping Duplicates:
#        Age  Attrition BusinessTravel  DailyRate              Department  \
# 0       41          1  Travel_Rarely       1102                   Sales
# 1       41          1  Travel_Rarely       1102                   Sales
# 2       41          1  Travel_Rarely       1102                   Sales
# 3       41          1  Travel_Rarely       1102                   Sales
# 4       41          1  Travel_Rarely       1102                   Sales
# ...    ...        ...            ...        ...                     ...
# 23199   60          0  Travel_Rarely        370  Research & Development
# 23200   60          0  Travel_Rarely        370  Research & Development
# ...

# %%
df1
# Out:
#        Age  Attrition BusinessTravel  DailyRate              Department  \
# 0       41          1  Travel_Rarely       1102                   Sales
# 1       41          1  Travel_Rarely       1102                   Sales
# 2       41          1  Travel_Rarely       1102                   Sales
# 3       41          1  Travel_Rarely       1102                   Sales
# 4       41          1  Travel_Rarely       1102                   Sales
# ...    ...        ...            ...        ...                     ...
# 23199   60          0  Travel_Rarely        370  Research & Development
# 23200   60          0  Travel_Rarely        370  Research & Development
# 23201   60          0  Travel_Rarely        370  Research & Development
# 23202   60          0  Travel_Rarely        370  Research & Development
# 23203   60          0  Travel_Rarely        370  Research & Development
#
#        DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.nunique().sort_values()
# Out:
# Over18                          1
# StandardHours                   1
# EmployeeCount                   1
# Gender                          2
# Attrition                       2
# PerformanceRating               2
# OverTime                        2
# JobInvolvement                  3
# MaritalStatus                   3
# Department                      3
# BusinessTravel                  3
# StockOptionLevel                4
# EnvironmentSatisfaction         4
# JobSatisfaction                 4
# RelationshipSatisfaction        4
# WorkLifeBalance                 4
# Education                       5
# JobLevel                        5
# TrainingTimesLastYear           7
# EducationField                  7
# NumCompaniesWorked              8
# JobRole                         9
# PercentSalaryHike              15
# YearsSinceLastPromotion        16
# YearsWithCurrManager           18
# YearsInCurrentRole             19
# DistanceFromHome               29
# ...

# %%
df3 = df1.drop_duplicates(subset="EmployeeNumber", keep="first")

df3
# Out:
#        Age  Attrition BusinessTravel  DailyRate              Department  \
# 0       41          1  Travel_Rarely       1102                   Sales
# 2       41          1  Travel_Rarely       1102                   Sales
# 3       41          1  Travel_Rarely       1102                   Sales
# 4       41          1  Travel_Rarely       1102                   Sales
# 5       41          1  Travel_Rarely       1102                   Sales
# ...    ...        ...            ...        ...                     ...
# 23199   60          0  Travel_Rarely        370  Research & Development
# 23200   60          0  Travel_Rarely        370  Research & Development
# 23201   60          0  Travel_Rarely        370  Research & Development
# 23202   60          0  Travel_Rarely        370  Research & Development
# 23203   60          0  Travel_Rarely        370  Research & Development
#
#        DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df3.nunique().sort_values()
# Out:
# Over18                          1
# StandardHours                   1
# EmployeeCount                   1
# Gender                          2
# Attrition                       2
# PerformanceRating               2
# OverTime                        2
# JobInvolvement                  3
# MaritalStatus                   3
# Department                      3
# BusinessTravel                  3
# StockOptionLevel                4
# EnvironmentSatisfaction         4
# JobSatisfaction                 4
# RelationshipSatisfaction        4
# WorkLifeBalance                 4
# Education                       5
# JobLevel                        5
# TrainingTimesLastYear           7
# EducationField                  7
# NumCompaniesWorked              8
# JobRole                         9
# PercentSalaryHike              15
# YearsSinceLastPromotion        16
# YearsWithCurrManager           18
# YearsInCurrentRole             19
# DistanceFromHome               29
# ...

# %% [markdown]
# # Drop useless fetures and rename the dataframe

# %%
df2 = df3.drop(labels = ['Over18','StandardHours','EmployeeCount'], axis = 1)

# %% [markdown]
# # Moving Response Variable to the last column

# %%
# Moving Response Variable to the last column
front = df2['Attrition']
df2.drop(labels=['Attrition'], axis=1,inplace=True)
df2.insert(31,'Attrition',front)
df2.head()
# Out:
#    Age BusinessTravel  DailyRate Department  DistanceFromHome  Education  \
# 0   41  Travel_Rarely       1102      Sales                 1          2
# 2   41  Travel_Rarely       1102      Sales                 1          2
# 3   41  Travel_Rarely       1102      Sales                 1          2
# 4   41  Travel_Rarely       1102      Sales                 1          2
# 5   41  Travel_Rarely       1102      Sales                 1          2
#
#   EducationField EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0  Life Sciences              1                        2  Female          94
# 2  Life Sciences              7                        2  Female          94
# 3  Life Sciences              8                        2  Female          94
# 4  Life Sciences              9                        2  Female          94
# 5  Life Sciences             10                        4  Female          33
#
# ...

# %% [markdown]
# # Changing object types to categories

# %%
# Changing object types to categories
cols = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
for col in cols:
    df2[col] = df2[col].astype('category')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23141 entries, 0 to 23203
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23141 non-null  int64
#  1   BusinessTravel            23141 non-null  category
#  2   DailyRate                 23141 non-null  int64
#  3   Department                23141 non-null  category
#  4   DistanceFromHome          23141 non-null  int64
#  5   Education                 23141 non-null  int64
#  6   EducationField            23141 non-null  category
#  7   EmployeeNumber            23141 non-null  object
#  8   EnvironmentSatisfaction   23141 non-null  int64
#  9   Gender                    23141 non-null  category
#  10  HourlyRate                23141 non-null  int64
#  11  JobInvolvement            23141 non-null  int64
#  12  JobLevel                  23141 non-null  int64
# ...

# %%
df2["EmployeeNumber"].dtype
# Out:
# dtype('O')

# %%
# Convert column 'A' to int
#df2["EmployeeNumber"] = df2["EmployeeNumber"].astype(int)
# Convert column 'A' to int, handling non-numeric values
df2["EmployeeNumber"] = pd.to_numeric(df2["EmployeeNumber"], errors="coerce")  # Convert invalid values to NaN
df2["EmployeeNumber"] = df2["EmployeeNumber"].fillna(0).astype(int)  # Replace NaN with 0 and convert to int

df2
# Out:
#        Age BusinessTravel  DailyRate              Department  \
# 0       41  Travel_Rarely       1102                   Sales
# 2       41  Travel_Rarely       1102                   Sales
# 3       41  Travel_Rarely       1102                   Sales
# 4       41  Travel_Rarely       1102                   Sales
# 5       41  Travel_Rarely       1102                   Sales
# ...    ...            ...        ...                     ...
# 23199   60  Travel_Rarely        370  Research & Development
# 23200   60  Travel_Rarely        370  Research & Development
# 23201   60  Travel_Rarely        370  Research & Development
# 23202   60  Travel_Rarely        370  Research & Development
# 23203   60  Travel_Rarely        370  Research & Development
#
#        DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                     1          2  Life Sciences               1
# 2                     1          2  Life Sciences               7
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23141 entries, 0 to 23203
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23141 non-null  int64
#  1   BusinessTravel            23141 non-null  category
#  2   DailyRate                 23141 non-null  int64
#  3   Department                23141 non-null  category
#  4   DistanceFromHome          23141 non-null  int64
#  5   Education                 23141 non-null  int64
#  6   EducationField            23141 non-null  category
#  7   EmployeeNumber            23141 non-null  int64
#  8   EnvironmentSatisfaction   23141 non-null  int64
#  9   Gender                    23141 non-null  category
#  10  HourlyRate                23141 non-null  int64
#  11  JobInvolvement            23141 non-null  int64
#  12  JobLevel                  23141 non-null  int64
# ...

# %%
df2.nunique().sort_values()
# Out:
# Attrition                       2
# PerformanceRating               2
# OverTime                        2
# Gender                          2
# JobInvolvement                  3
# MaritalStatus                   3
# Department                      3
# BusinessTravel                  3
# WorkLifeBalance                 4
# EnvironmentSatisfaction         4
# StockOptionLevel                4
# RelationshipSatisfaction        4
# JobSatisfaction                 4
# JobLevel                        5
# Education                       5
# EducationField                  7
# TrainingTimesLastYear           7
# NumCompaniesWorked              8
# JobRole                         9
# PercentSalaryHike              15
# YearsSinceLastPromotion        16
# YearsWithCurrManager           18
# YearsInCurrentRole             19
# DistanceFromHome               29
# YearsAtCompany                 37
# TotalWorkingYears              40
# Age                            43
# ...

# %%
df2.shape
# Out:
# (23141, 32)

# %%
df2 = df2.drop_duplicates(subset="EmployeeNumber", keep="first")

df2
# Out:
#        Age BusinessTravel  DailyRate              Department  \
# 0       41  Travel_Rarely       1102                   Sales
# 2       41  Travel_Rarely       1102                   Sales
# 3       41  Travel_Rarely       1102                   Sales
# 4       41  Travel_Rarely       1102                   Sales
# 5       41  Travel_Rarely       1102                   Sales
# ...    ...            ...        ...                     ...
# 23199   60  Travel_Rarely        370  Research & Development
# 23200   60  Travel_Rarely        370  Research & Development
# 23201   60  Travel_Rarely        370  Research & Development
# 23202   60  Travel_Rarely        370  Research & Development
# 23203   60  Travel_Rarely        370  Research & Development
#
#        DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                     1          2  Life Sciences               1
# 2                     1          2  Life Sciences               7
# ...

# %% [markdown]
# # Inspect the values of categorical columns

# %%
df2[cols].nunique()
# Out:
# BusinessTravel    3
# Department        3
# EducationField    7
# Gender            2
# JobRole           9
# MaritalStatus     3
# OverTime          2
# dtype: int64

# %%
for col in cols:
    display(df2[col].value_counts())
# Out:
# BusinessTravel
# Travel_Rarely        16411
# Travel_Frequently     4367
# Non-Travel            2362
# Name: count, dtype: int64
# Department
# Research & Development    15098
# Sales                      7039
# Human Resources            1003
# Name: count, dtype: int64
# EducationField
# Life Sciences       9550
# Medical             7285
# Marketing           2519
# Technical Degree    2047
# Other               1302
# Human Resources      436
# Test                   1
# Name: count, dtype: int64
# Gender
# Male      13883
# Female     9257
# Name: count, dtype: int64
# JobRole
# Sales Executive              5036
# Research Scientist           4580
# Laboratory Technician        4097
# Manufacturing Director       2357
# Healthcare Representative    2073
# Manager                      1584
# Sales Representative         1299
# Research Director            1279
# Human Resources               835
# Name: count, dtype: int64
# MaritalStatus
# Married     10590
# Single       7397
# ...

# %%
# Get the index of rows to drop
row_index_to_drop = df2.index[df2["EducationField"] == "Test"]

# Drop the row(s)
df2 = df2.drop(row_index_to_drop)

# %%
for col in cols:
    display(df2[col].value_counts())
# Out:
# BusinessTravel
# Travel_Rarely        16410
# Travel_Frequently     4367
# Non-Travel            2362
# Name: count, dtype: int64
# Department
# Research & Development    15097
# Sales                      7039
# Human Resources            1003
# Name: count, dtype: int64
# EducationField
# Life Sciences       9550
# Medical             7285
# Marketing           2519
# Technical Degree    2047
# Other               1302
# Human Resources      436
# Test                   0
# Name: count, dtype: int64
# Gender
# Male      13882
# Female     9257
# Name: count, dtype: int64
# JobRole
# Sales Executive              5036
# Research Scientist           4580
# Laboratory Technician        4097
# Manufacturing Director       2357
# Healthcare Representative    2072
# Manager                      1584
# Sales Representative         1299
# Research Director            1279
# Human Resources               835
# Name: count, dtype: int64
# MaritalStatus
# Married     10589
# Single       7397
# ...

# %%
df2.nunique().sort_values()
# Out:
# Attrition                       2
# PerformanceRating               2
# OverTime                        2
# Gender                          2
# JobInvolvement                  3
# MaritalStatus                   3
# Department                      3
# BusinessTravel                  3
# WorkLifeBalance                 4
# EnvironmentSatisfaction         4
# StockOptionLevel                4
# RelationshipSatisfaction        4
# JobSatisfaction                 4
# JobLevel                        5
# Education                       5
# EducationField                  6
# TrainingTimesLastYear           7
# NumCompaniesWorked              8
# JobRole                         9
# PercentSalaryHike              15
# YearsSinceLastPromotion        16
# YearsWithCurrManager           18
# YearsInCurrentRole             19
# DistanceFromHome               29
# YearsAtCompany                 37
# TotalWorkingYears              40
# Age                            43
# ...
